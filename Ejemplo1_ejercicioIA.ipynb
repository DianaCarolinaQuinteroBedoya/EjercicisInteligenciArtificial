# %% [markdown]
# # Implementación - Búsqueda No Informada

# %%
class SearchProblem:

    'clase abstracta para la implementación de problemas de búsqueda'

    def __init__(self, initial, goal):
        self.initial = initial
        self.goal = goal

    def actions(self, state):
        'retorna las acciones disponibles para stats'
        return NotImplementedError
    
    def  result(self, state):
        'retorna el estado resultante de aplicar la acción al estado actual'
        return NotImplementedError

    def is_goal(self, state):
        'Determina si el estado actual es el estado objetivo'
        return self.goal == state

    def cost(self, state, action):
        'costo de aplicar una acción a un estado'
        return 1

# %%
class EjemploBFS(SearchProblem):
    def action(self, state):
        action = {"S":["A", "D"],
        "A": ["B"],
        "B": ["C", "G"],
        "C": ["G"],
        "D": ["G"],
        }
        return action[state]

    def result (self, state, action):
        return action 

problem = EjemploBFS(initial = 'S', goal='G')

# %%
#ejemplo de pila y cola
fringe =  [1,2,3,4,5]
print(fringe)
fringe.pop(0)
print(fringe)
fringe.append(3)

print(fringe)
# Out:
# [1, 2, 3, 4, 5]
# [2, 3, 4, 5]
# [2, 3, 4, 5, 3]

# %%
'Algoritmo de búsqueda'
def search(problem, fringe=[]):
    closed = []
    fringe.append(problem.initial)
    print(fringe)
    while(True):
        if not fringe: 
            return "failure"
            node = fringe.pop(0)
        if goal(problem, state[node]): 
            return node
        if node is not closed:
            

        
search(problem)
# Out:
#   Input In [4]
#     search(problem)
#                    ^
# IndentationError: expected an indented block

# %%
a = []
b = [1]

print(bool(a), bool(b))

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=011d8d90-4c67-47d5-9ec8-32e834081782' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
